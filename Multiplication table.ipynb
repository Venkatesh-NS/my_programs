# %% [markdown]
# ## Multiplication table from 10 to 20

# %%
for i in range (10,21):
  print(f"Multiplication table of {i} \n***************************")
  for j in range (1,11):
    print(f"{i}X{j}={i*j}")
    if j==10:
      print( )
# Out:
# Multiplication table of 10
# ***************************
# 10X1=10
# 10X2=20
# 10X3=30
# 10X4=40
# 10X5=50
# 10X6=60
# 10X7=70
# 10X8=80
# 10X9=90
# 10X10=100
#
# Multiplication table of 11
# ***************************
# 11X1=11
# 11X2=22
# 11X3=33
# 11X4=44
# 11X5=55
# 11X6=66
# 11X7=77
# 11X8=88
# 11X9=99
# 11X10=110
#
# Multiplication table of 12
# ***************************
# 12X1=12
# 12X2=24
# 12X3=36
# 12X4=48
# 12X5=60
# 12X6=72
# 12X7=84
# 12X8=96
# 12X9=108
# 12X10=120
#
# Multiplication table of 13
# ***************************
# 13X1=13
# 13X2=26
# 13X3=39
# 13X4=52
# 13X5=65
# 13X6=78
# 13X7=91
# 13X8=104
# 13X9=117
# 13X10=130
#
# Multiplication table of 14
# ***************************
# 14X1=14
# 14X2=28
# 14X3=42
# 14X4=56
# 14X5=70
# 14X6=84
# 14X7=98
# 14X8=112
# 14X9=126
# 14X10=140
#
# Multiplication table of 15
# ***************************
# 15X1=15
# 15X2=30
# 15X3=45
# 15X4=60
# 15X5=75
# 15X6=90
# 15X7=105
# 15X8=120
# 15X9=135
# 15X10=150
#
# ...
